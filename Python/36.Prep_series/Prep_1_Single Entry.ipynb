# %% [markdown]
# ![Single_entry_1.PNG](attachment:Single_entry_1.PNG)

# %% [markdown]
# ![Single_entry_2.PNG](attachment:Single_entry_2.PNG)

# %%
n = list(map(int, input().split()))
unique = set(n)
for num in unique:
    if n.count(num) == 1:
        print(num)
# Out:
# 2 2 1
# 1

# %%
n = list(map(int, input().split()))
unique = set(n)
for num in unique:
    if n.count(num) == 1:
        print(num)
# Out:
# 8 9 2 8 9 2 5
# 5
